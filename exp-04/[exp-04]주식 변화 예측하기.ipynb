# %% [markdown]
# # 주식 예측에 도전해 보자

# %% [markdown]
# ## 1) 필요한 모듈 import

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os


from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %% [markdown]
# ## STEP1. 시계열 데이터 준비

# %%
# Time Series 생성
dataset_filepath = 'C:/Users/strfg/OneDrive/바탕 화면/AIFFEL-exploration/exp-04/data/005930.KS.csv' 
#samsung 데이터
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()
# Out:
# Date
# 2020-05-18    48800.0
# 2020-05-19    50300.0
# 2020-05-20    50000.0
# 2020-05-21    49950.0
# 2020-05-22    48750.0
# Name: Close, dtype: float64

# %% [markdown]
# ## STEP2. 각종 전처리 수행

# %%
# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %%
# 로그 변환
ts_log = np.log(ts)
plt.plot(ts_log)

# %% [markdown]
# ## STEP3. 시계열 안정성 분석

# %% [markdown]
# - 정성적 그래프 분석
# - 정량적 Augmented Dickey-Fuller Test
# - 시계열 분해(Time Series Decomposition)
# - Residual 안정성 확인

# %% [markdown]
# - 정성적 그래프 분석 함수

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  # 이동평균 시계열
    rolstd = timeseries.rolling(window=window).std()    # 이동표준편차 시계열

     # 원본시계열, 이동평균, 이동표준편차를 plot으로 시각화해 본다.
    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %% [markdown]
# - 정량적 Augmented Dicky-Fuller Test 함수

# %%
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메서드를 호출합니다.
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메서드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.383525
# p-value                          0.590149
# #Lags Used                       0.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64

# %%
# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.187586e+00
# p-value                        6.234854e-08
# #Lags Used                     9.000000e+00
# Number of Observations Used    2.100000e+02
# Critical Value (1%)           -3.461879e+00
# Critical Value (5%)           -2.875404e+00
# Critical Value (10%)          -2.574159e+00
# dtype: float64

# %% [markdown]
# ## STEP4. 학습, 테스트 데이터셋 생성

# %% [markdown]
# - 학습, 테스트 데이터셋 분리

# %%
train_data, test_data = train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# ## STEP5. 적정 ARIMA 모수 찾기

# %% [markdown]
# - ACF, PACF 그려보기 -> p,q 구하기
# - 차분 안정성 확인 -> d 구하기

# %%
# ACF, PACF 그려보기 -> p,q 구하기

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.553699e+01
# p-value                        2.183738e-28
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.480000e+02
# Critical Value (1%)           -3.456996e+00
# Critical Value (5%)           -2.873266e+00
# Critical Value (10%)          -2.573019e+00
# dtype: float64

# %% [markdown]
# - p-value가 거의 0에 가깝게 나와 굳이 차분을 할 필요가 없어 보인다.

# %% [markdown]
# ## STEP6. ARIMA 모델 훈련과 테스트

# %% [markdown]
# - ARIMA 모델 빌드와 훈련
# - 모델 테스트 및 플로팅
# - 최종 예측 모델 정확도 측정(MAPE)

# %%
# Build and Train  Model
model = ARIMA(train_data, order=(2, 0, 1))  
fitted_m = model.fit() 

print(fitted_m.summary())
# Out:
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  225
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                 583.361
# Date:                Fri, 29 Jul 2022   AIC                          -1156.722
# Time:                        23:58:11   BIC                          -1139.642
# Sample:                             0   HQIC                         -1149.828
#                                 - 225
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.0896      0.129     86.277      0.000      10.838      11.342
# ar.L1          0.7739      1.821      0.425      0.671      -2.796       4.344
# ar.L2          0.2191      1.811      0.121      0.904      -3.331       3.769
# ma.L1          0.2595      1.813      0.143      0.886      -3.294       3.813
# sigma2         0.0003   2.56e-05     12.526      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                20.44
# Prob(Q):                              0.63   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.95   Skew:                             0.50
# Prob(H) (two-sided):                  0.81   Kurtosis:                         4.08
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()
# Out:
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
test_data = np.exp(test_data)
fc = np.exp(fc)
mse = mean_squared_error(test_data, fc)
print('MSE: ', mse)

mae = mean_absolute_error(test_data, fc)
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: ', rmse)

mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  1048973.6014239227
# MAE:  843.757953150685
# RMSE:  1024.1941229200268
# MAPE: 1.03%

# %% [markdown]
# ## STEP7. 다른 주식 종목 예측해 보기

# %% [markdown]
# - 한화 에어로스페이스(012450.KS)
# - 소프트뱅크(9984.T)
# - 현대차(005380.KS)

# %% [markdown]
# ### 한화 에어로스페이스

# %%
# Time Series 생성
dataset_filepath = 'C:/Users/strfg/OneDrive/바탕 화면/AIFFEL-exploration/exp-04/data/012450.KS.csv' 
# 한화 에어로스페이스 데이터
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()

# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]

# 로그 변환
ts_log = np.log(ts)
plt.plot(ts_log)

# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)

# 학습, 테스트 데이터셋 분리
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# ACF, PACF 그려보기 -> p,q 구하기

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.894570
# p-value                          0.334620
# #Lags Used                       0.000000
# Number of Observations Used    244.000000
# Critical Value (1%)             -3.457438
# Critical Value (5%)             -2.873459
# Critical Value (10%)            -2.573122
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.376768
# p-value                          0.000004
# #Lags Used                       0.000000
# Number of Observations Used    214.000000
# Critical Value (1%)             -3.461282
# Critical Value (5%)             -2.875143
# Critical Value (10%)            -2.574020
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -1.407016e+01
# p-value                        2.950026e-26
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.430000e+02
# Critical Value (1%)           -3.457551e+00
# Critical Value (5%)           -2.873509e+00
# Critical Value (10%)          -2.573148e+00
# dtype: float64

# %%
# 아리마 모델 훈련 및 테스트

# Build and Train  Model
model = ARIMA(train_data, order=(12, 1, 2))  
fitted_m = model.fit() 

print(fitted_m.summary())

# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()
# Out:
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  220
# Model:                ARIMA(12, 1, 2)   Log Likelihood                 491.550
# Date:                Sat, 30 Jul 2022   AIC                           -953.101
# Time:                        00:00:17   BIC                           -902.265
# Sample:                             0   HQIC                          -932.569
#                                 - 220
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0178      1.773     -0.010      0.992      -3.493       3.457
# ar.L2          0.3589      0.557      0.644      0.520      -0.733       1.451
# ar.L3          0.0210      0.090      0.232      0.816      -0.156       0.198
# ar.L4         -0.0824      0.088     -0.933      0.351      -0.256       0.091
# ar.L5          0.0158      0.172      0.092      0.927      -0.322       0.353
# ar.L6          0.0645      0.109      0.589      0.556      -0.150       0.279
# ar.L7         -0.0808      0.096     -0.839      0.402      -0.270       0.108
# ar.L8         -0.0745      0.161     -0.462      0.644      -0.390       0.242
# ar.L9          0.0391      0.142      0.275      0.784      -0.240       0.318
# ar.L10        -0.0863      0.101     -0.852      0.394      -0.285       0.112
# ar.L11        -0.1094      0.194     -0.564      0.572      -0.489       0.271
# ar.L12         0.0463      0.232      0.200      0.841      -0.408       0.500
# ma.L1         -0.0381      1.786     -0.021      0.983      -3.538       3.462
# ma.L2         -0.3435      0.545     -0.631      0.528      -1.411       0.724
# sigma2         0.0007   5.27e-05     12.439      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                62.17
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.17   Skew:                            -0.42
# Prob(H) (two-sided):                  0.50   Kurtosis:                         5.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# test 데이터와 결과를 다시 원래 스케일로 복구
test_data = np.exp(test_data)
fc = np.exp(fc)
mse = mean_squared_error(test_data, fc)
print('MSE: ', mse)

mae = mean_absolute_error(test_data, fc)
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: ', rmse)

mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  28376859.788131293
# MAE:  4312.840425755846
# RMSE:  5326.993503668959
# MAPE: 9.14%

# %% [markdown]
# - 한화 에어로스페이스의 경우 갑자기 값이 확 올라버려 예상치보다 상회하는 결과가 나왔다.

# %% [markdown]
# ### 소프트뱅크(9984.T)

# %%
# Time Series 생성
dataset_filepath = 'C:/Users/strfg/OneDrive/바탕 화면/AIFFEL-exploration/exp-04/data/9984.T.csv' 
# 소프트뱅크 데이터
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()

# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]

# 로그 변환
ts_log = np.log(ts)
plt.plot(ts_log)

# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)

# 학습, 테스트 데이터셋 분리
train_data, test_data = train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# ACF, PACF 그려보기 -> p,q 구하기

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.478855
# p-value                          0.120704
# #Lags Used                       0.000000
# Number of Observations Used    245.000000
# Critical Value (1%)             -3.457326
# Critical Value (5%)             -2.873410
# Critical Value (10%)            -2.573096
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.198225
# p-value                          0.000009
# #Lags Used                       2.000000
# Number of Observations Used    213.000000
# Critical Value (1%)             -3.461429
# Critical Value (5%)             -2.875207
# Critical Value (10%)            -2.574054
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -1.565885e+01
# p-value                        1.563075e-28
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.440000e+02
# Critical Value (1%)           -3.457438e+00
# Critical Value (5%)           -2.873459e+00
# Critical Value (10%)          -2.573122e+00
# dtype: float64

# %%
# 아리마 모델 훈련 및 테스트

# Build and Train  Model
model = ARIMA(train_data, order=(19, 1, 1))  
fitted_m = model.fit() 

print(fitted_m.summary())

# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()
# Out:
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  221
# Model:                ARIMA(19, 1, 1)   Log Likelihood                 463.011
# Date:                Sat, 30 Jul 2022   AIC                           -884.021
# Time:                        00:02:27   BIC                           -812.755
# Sample:                             0   HQIC                          -855.242
#                                 - 221
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2208      1.014     -0.218      0.828      -2.209       1.767
# ar.L2          0.0331      0.088      0.375      0.708      -0.140       0.206
# ar.L3         -0.0435      0.101     -0.429      0.668      -0.242       0.155
# ar.L4         -0.0247      0.094     -0.264      0.792      -0.208       0.159
# ar.L5         -0.0484      0.082     -0.593      0.553      -0.208       0.112
# ar.L6         -0.0323      0.086     -0.376      0.707      -0.201       0.136
# ar.L7         -0.0973      0.085     -1.145      0.252      -0.264       0.069
# ar.L8         -0.0165      0.121     -0.136      0.892      -0.254       0.221
# ar.L9         -0.0221      0.068     -0.325      0.745      -0.156       0.111
# ar.L10        -0.0966      0.075     -1.281      0.200      -0.244       0.051
# ar.L11        -0.0767      0.117     -0.655      0.512      -0.306       0.153
# ar.L12        -0.0372      0.093     -0.399      0.690      -0.220       0.145
# ar.L13        -0.0034      0.097     -0.035      0.972      -0.194       0.187
# ar.L14        -0.0482      0.091     -0.532      0.595      -0.226       0.130
# ar.L15        -0.0690      0.102     -0.678      0.498      -0.268       0.131
# ar.L16        -0.1318      0.106     -1.249      0.212      -0.339       0.075
# ar.L17         0.0477      0.145      0.328      0.743      -0.237       0.332
# ar.L18         0.0317      0.110      0.289      0.773      -0.183       0.247
# ar.L19        -0.0741      0.085     -0.869      0.385      -0.241       0.093
# ma.L1          0.2076      1.015      0.204      0.838      -1.783       2.198
# sigma2         0.0009   7.76e-05     11.169      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                20.08
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.46   Skew:                             0.11
# Prob(H) (two-sided):                  0.11   Kurtosis:                         4.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# test 데이터와 결과를 다시 원래 스케일로 복구
test_data = np.exp(test_data)
fc = np.exp(fc)
mse = mean_squared_error(test_data, fc)
print('MSE: ', mse)

mae = mean_absolute_error(test_data, fc)
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: ', rmse)

mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  76840.81107793235
# MAE:  236.1782671418609
# RMSE:  277.2017515780381
# MAPE: 4.30%

# %% [markdown]
# ### 현대차(005380.KS)

# %%
# Time Series 생성
dataset_filepath = 'C:/Users/strfg/OneDrive/바탕 화면/AIFFEL-exploration/exp-04/data/005380.KS.csv' 
# 현대차 데이터
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()

# 결측치 처리
ts = ts.interpolate(method='time')
ts[ts.isna()]

# 로그 변환
ts_log = np.log(ts)
plt.plot(ts_log)

# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.rcParams["figure.figsize"] = (11,6)
plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# Residual 안정성 확인
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)

# 학습, 테스트 데이터셋 분리
train_data, test_data = train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')  # train_data를 적용하면 그래프가 끊어져 보이므로 자연스러운 연출을 위해 ts_log를 선택
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# ACF, PACF 그려보기 -> p,q 구하기

plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# 차분 안정성 확인 -> d 구하기
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.823090
# p-value                          0.369060
# #Lags Used                       2.000000
# Number of Observations Used    242.000000
# Critical Value (1%)             -3.457664
# Critical Value (5%)             -2.873559
# Critical Value (10%)            -2.573175
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -5.791363e+00
# p-value                        4.863694e-07
# #Lags Used                     5.000000e+00
# Number of Observations Used    2.090000e+02
# Critical Value (1%)           -3.462032e+00
# Critical Value (5%)           -2.875471e+00
# Critical Value (10%)          -2.574195e+00
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                -1.254359e+01
# p-value                        2.286085e-23
# #Lags Used                     1.000000e+00
# Number of Observations Used    2.420000e+02
# Critical Value (1%)           -3.457664e+00
# Critical Value (5%)           -2.873559e+00
# Critical Value (10%)          -2.573175e+00
# dtype: float64

# %%
# 아리마 모델 훈련 및 테스트

# Build and Train  Model
model = ARIMA(train_data, order=(21, 1, 2))  
fitted_m = model.fit() 

print(fitted_m.summary())

# Forecast : 결과가 fc에 담깁니다. 
fc = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf
fc = np.array(fc)

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.legend()
plt.show()
# Out:
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  220
# Model:                ARIMA(21, 1, 2)   Log Likelihood                 609.932
# Date:                Sat, 30 Jul 2022   AIC                          -1171.865
# Time:                        00:03:36   BIC                          -1090.527
# Sample:                             0   HQIC                         -1139.015
#                                 - 220
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0752      0.421      0.178      0.858      -0.750       0.901
# ar.L2         -0.7016      0.535     -1.312      0.189      -1.749       0.346
# ar.L3          0.0616      0.116      0.533      0.594      -0.165       0.288
# ar.L4         -0.1743      0.121     -1.442      0.149      -0.411       0.063
# ar.L5          0.0454      0.113      0.400      0.689      -0.177       0.268
# ar.L6         -0.0848      0.095     -0.896      0.370      -0.270       0.101
# ar.L7         -0.0028      0.120     -0.023      0.981      -0.238       0.233
# ar.L8          0.0022      0.088      0.026      0.980      -0.170       0.175
# ar.L9          0.0292      0.120      0.243      0.808      -0.206       0.265
# ar.L10         0.0026      0.100      0.026      0.979      -0.194       0.199
# ar.L11         0.0496      0.115      0.432      0.666      -0.175       0.275
# ar.L12        -0.0238      0.115     -0.208      0.835      -0.249       0.201
# ar.L13         0.0846      0.112      0.758      0.448      -0.134       0.304
# ar.L14        -0.0637      0.116     -0.548      0.584      -0.292       0.164
# ar.L15         0.0303      0.133      0.229      0.819      -0.230       0.290
# ar.L16        -0.0064      0.096     -0.067      0.947      -0.195       0.182
# ar.L17        -0.0684      0.111     -0.615      0.539      -0.287       0.150
# ar.L18         0.0297      0.098      0.303      0.762      -0.162       0.222
# ar.L19         0.0126      0.105      0.119      0.905      -0.194       0.219
# ar.L20         0.0091      0.114      0.080      0.936      -0.215       0.233
# ar.L21        -0.0835      0.110     -0.758      0.449      -0.300       0.133
# ma.L1         -0.0132      0.439     -0.030      0.976      -0.873       0.847
# ma.L2          0.5761      0.509      1.133      0.257      -0.421       1.573
# sigma2         0.0002      2e-05     11.099      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):                31.52
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.34   Skew:                            -0.35
# Prob(H) (two-sided):                  0.22   Kurtosis:                         4.72
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\Users\strfg\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# test 데이터와 결과를 다시 원래 스케일로 복구
test_data = np.exp(test_data)
fc = np.exp(fc)
mse = mean_squared_error(test_data, fc)
print('MSE: ', mse)

mae = mean_absolute_error(test_data, fc)
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(test_data, fc))
print('RMSE: ', rmse)

mape = np.mean(np.abs(fc - test_data)/np.abs(test_data))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  179089822.09825107
# MAE:  11444.14653320849
# RMSE:  13382.444548670885
# MAPE: 6.06%

# %% [markdown]
# # 회고
#
# ## 이번 프로젝트에서 **어려웠던 점**
#     - 이번 프로젝트에서 p, d, q의 설정하는 것에 어려움을 겪었다.
# ## 프로젝트를 진행하면서 **알아낸 점** 혹은 **아직 모호한 점**.
#     - 한화 에어로스페이스, 소프트뱅크, 현대차 모두 마지막에 주식 가격이 갑자기 오르는 경향을 보여 삼성전자의 예측치와는 달리 오차가 커 아리마 모델 하나만 가지고는 예측하는 것은 위험하다는 것을 확인할 수 있었다.(다른 모델도 같이 써 평균을 내는 것으로 보완할 수 있을듯 하다.)
